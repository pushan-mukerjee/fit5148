# %%
# Libraries
import socket
import sys
import time
import random
import datetime as dt
import pandas as pd
import json

# %%
#Reading the ClimateData-Part2.csv into an array of values
climateDf=pd.read_csv('ClimateData-Part2.csv', sep=',',header=0)
climateRecords = climateDf.values
climateRecords = climateRecords.tolist()

#Reading the FireData-Part2.csv into an array of values
fireDf=pd.read_csv('FireData-Part2.csv', sep=',',header=0)
fireRecords = fireDf.values
fireRecords = fireRecords.tolist()

# %%
# Create a TCP/IP socket
climateSock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
fireSock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# Bind the socket to the port
server_address = ('localhost', 8085)
print('['+ str(dt.datetime.now())+'] Starting streaming server on {}:{}'.format(*server_address))
climateSock.bind(server_address)

# Bind the socket to the port
server_address2 = ('localhost', 9997)
print('['+ str(dt.datetime.now())+'] Starting streaming server on {}:{}'.format(*server_address2))
fireSock.bind(server_address2)

# Listen for incoming connections
climateSock.listen(1)
fireSock.listen(1)

i = 0 #initialise record counter
while True: #while connected
    # Wait for a connection
    print('['+ str(dt.datetime.now())+'] Waiting for a connection...')
    connection, client_address = climateSock.accept()
    connection2, client_address2 = fireSock.accept()
    try:
        print('['+ str(dt.datetime.now())+'] Connection from', client_address)
        print('['+ str(dt.datetime.now())+'] Connection from', client_address2)
        # Get the random line from lines array
        datestamp = str(dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

        if (i < len(climateRecords)):
            climateRec = climateRecords[i] #pick the next climateData record to send
            climateRec.append(datestamp) #append the event datestamp as joining attribute with fire
            connection.sendall(str(climateRec).encode())
            print ('Climate Data Sent: ' + str(climateRec))
        
        if (i < len(fireRecords) // 5):
            startRec = 5 * i #define the start record index of the fireData batch
            if (len(fireRecords) - startRec < 5): #if the last batch of fireData records, get all remaining records
                endRec = (5*i) + (len(fireRecords) - startRec)
            else: #Else pick the next 5 fireData records to send in the fire batch
                endRec = (5*i) + 5
            fireRecs = fireRecords[startRec:endRec] #fire records for sending

            for fireRec in fireRecs: #Loop through the fireData records and add them to the batch of 5 to be sent
                fireRec.append(datestamp) #append the event datestamp as joining attribute with climate
                connection2.sendall(str(fireRec).encode()) #Send the FireData batch
                print ('FireData Sent: ' + str(fireRec)) #Print the FireData batch
        i += 1  #increment the record counter  
        time.sleep(1)
    finally:
        # Clean up the connection
        connection.close()
        connection2.close()
# Out:
# [2018-10-08 02:58:43.070744] Starting streaming server on localhost:8085
# [2018-10-08 02:58:43.071977] Starting streaming server on localhost:9997
# [2018-10-08 02:58:43.075167] Waiting for a connection...
# [2018-10-08 02:58:54.460755] Connection from ('127.0.0.1', 55260)
# [2018-10-08 02:58:54.461139] Connection from ('127.0.0.1', 47104)
# Climate Data Sent: ['cdata', 948700, 19, 56.8, 7.9, 11.1, ' 0.00I', '2018-10-08 02:58:54']
# FireData Sent: ['fdata', -37.966, 145.05100000000002, 341.8, 26.7, 78, 68, '2018-10-08 02:58:54']
# FireData Sent: ['fdata', -35.541, 143.311, 336.3, 62.0, 82, 63, '2018-10-08 02:58:54']
# FireData Sent: ['fdata', -35.554, 143.30700000000002, 326.8, 23.8, 67, 53, '2018-10-08 02:58:54']
# FireData Sent: ['fdata', -35.543, 143.316, 340.4, 84.2, 86, 67, '2018-10-08 02:58:54']
# FireData Sent: ['fdata', -37.708, 145.1, 327.8, 16.2, 80, 54, '2018-10-08 02:58:54']
# [2018-10-08 02:58:55.463915] Waiting for a connection...
# [2018-10-08 02:58:57.498948] Connection from ('127.0.0.1', 55268)
# [2018-10-08 02:58:57.499823] Connection from ('127.0.0.1', 47112)
# Climate Data Sent: ['cdata', 948700, 15, 50.7, 9.2, 13.0, ' 0.02G', '2018-10-08 02:58:57']
# FireData Sent: ['fdata', -35.646, 142.282, 305.6, 11.8, 65, 32, '2018-10-08 02:58:57']
# FireData Sent: ['fdata', -38.075, 143.76, 320.1, 17.6, 72, 46, '2018-10-08 02:58:57']
# FireData Sent: ['fdata', -37.635999999999996, 149.33, 316.7, 37.1, 94, 43, '2018-10-08 02:58:57']
# FireData Sent: ['fdata', -37.624, 149.332, 306.8, 20.8, 69, 33, '2018-10-08 02:58:57']
# FireData Sent: ['fdata', -37.82, 142.32299999999998, 327.6, 18.9, 62, 54, '2018-10-08 02:58:57']
# [2018-10-08 02:58:58.502879] Waiting for a connection...
# [2018-10-08 02:59:00.513397] Connection from ('127.0.0.1', 55276)
# [2018-10-08 02:59:00.513567] Connection from ('127.0.0.1', 47120)
# Climate Data Sent: ['cdata', 948700, 16, 53.6, 8.1, 15.0, ' 0.00G', '2018-10-08 02:59:00']
# FireData Sent: ['fdata', -37.875, 142.51, 346.2, 46.0, 93, 73, '2018-10-08 02:59:00']
# FireData Sent: ['fdata', -37.608000000000004, 149.328, 328.3, 69.3, 84, 55, '2018-10-08 02:59:00']
# FireData Sent: ['fdata', -37.613, 149.305, 348.2, 160.9, 95, 75, '2018-10-08 02:59:00']
# FireData Sent: ['fdata', -37.644, 149.346, 328.9, 63.5, 59, 55, '2018-10-08 02:59:00']
# FireData Sent: ['fdata', -37.624, 149.314, 340.1, 113.1, 90, 66, '2018-10-08 02:59:00']
# [2018-10-08 02:59:01.518048] Waiting for a connection...
# [2018-10-08 02:59:03.533690] Connection from ('127.0.0.1', 55280)
# [2018-10-08 02:59:03.533872] Connection from ('127.0.0.1', 47124)
# Climate Data Sent: ['cdata', 948700, 24, 61.6, 7.7, 14.0, ' 0.00I', '2018-10-08 02:59:03']
# FireData Sent: ['fdata', -37.661, 149.327, 329.7, 64.4, 75, 56, '2018-10-08 02:59:03']
# FireData Sent: ['fdata', -37.649, 149.322, 333.8, 78.9, 79, 60, '2018-10-08 02:59:03']
# FireData Sent: ['fdata', -38.056999999999995, 144.211, 346.3, 48.8, 93, 73, '2018-10-08 02:59:03']
# FireData Sent: ['fdata', -38.046, 144.201, 322.0, 11.8, 60, 48, '2018-10-08 02:59:03']
# FireData Sent: ['fdata', -38.048, 144.213, 329.0, 20.0, 82, 55, '2018-10-08 02:59:03']
# [2018-10-08 02:59:04.535470] Waiting for a connection...
# [2018-10-08 02:59:06.552362] Connection from ('127.0.0.1', 55286)
# [2018-10-08 02:59:06.552585] Connection from ('127.0.0.1', 47130)
# Climate Data Sent: ['cdata', 948700, 24, 62.3, 7.0, 13.0, ' 0.00I', '2018-10-08 02:59:06']
# FireData Sent: ['fdata', -37.650999999999996, 149.345, 337.8, 42.2, 82, 64, '2018-10-08 02:59:06']
# FireData Sent: ['fdata', -37.63, 149.335, 330.7, 27.8, 53, 57, '2018-10-08 02:59:06']
# FireData Sent: ['fdata', -37.626999999999995, 149.33, 315.9, 23.1, 92, 42, '2018-10-08 02:59:06']
# FireData Sent: ['fdata', -37.658, 149.339, 309.8, 17.3, 78, 36, '2018-10-08 02:59:06']
# FireData Sent: ['fdata', -37.623000000000005, 149.32299999999998, 311.9, 17.8, 51, 38, '2018-10-08 02:59:06']
# [2018-10-08 02:59:07.554454] Waiting for a connection...
# [2018-10-08 02:59:09.566706] Connection from ('127.0.0.1', 55290)
# [2018-10-08 02:59:09.566793] Connection from ('127.0.0.1', 47134)
# Climate Data Sent: ['cdata', 948700, 26, 60.8, 6.9, 12.0, ' 0.00I', '2018-10-08 02:59:09']
# FireData Sent: ['fdata', -38.038000000000004, 142.986, 313.4, 32.8, 65, 40, '2018-10-08 02:59:09']
# FireData Sent: ['fdata', -37.95, 142.366, 343.2, 58.7, 92, 70, '2018-10-08 02:59:09']
# FireData Sent: ['fdata', -38.231, 147.172, 333.3, 17.9, 83, 60, '2018-10-08 02:59:09']
# FireData Sent: ['fdata', -37.903, 145.25, 317.7, 10.4, 53, 44, '2018-10-08 02:59:09']
# FireData Sent: ['fdata', -37.986999999999995, 144.005, 311.2, 10.4, 50, 38, '2018-10-08 02:59:09']
# [2018-10-08 02:59:10.567567] Waiting for a connection...
# [2018-10-08 02:59:12.585635] Connection from ('127.0.0.1', 55292)
# [2018-10-08 02:59:12.585805] Connection from ('127.0.0.1', 47140)
# Climate Data Sent: ['cdata', 948700, 32, 54.1, 12.8, 19.0, ' 0.00I', '2018-10-08 02:59:12']
# FireData Sent: ['fdata', -34.289, 141.71200000000002, 327.7, 12.3, 67, 54, '2018-10-08 02:59:12']
# FireData Sent: ['fdata', -36.294000000000004, 146.149, 335.1, 28.7, 87, 61, '2018-10-08 02:59:12']
# FireData Sent: ['fdata', -36.285, 146.151, 327.8, 18.2, 81, 54, '2018-10-08 02:59:12']
# FireData Sent: ['fdata', -36.277, 146.165, 331.8, 24.5, 84, 58, '2018-10-08 02:59:12']
# FireData Sent: ['fdata', -36.275, 146.154, 333.6, 26.7, 86, 60, '2018-10-08 02:59:12']
# [2018-10-08 02:59:13.589082] Waiting for a connection...
# [2018-10-08 02:59:15.603330] Connection from ('127.0.0.1', 55298)
# [2018-10-08 02:59:15.603572] Connection from ('127.0.0.1', 47142)
# Climate Data Sent: ['cdata', 948700, 20, 57.7, 9.9, 18.1, ' 0.00I', '2018-10-08 02:59:15']
# FireData Sent: ['fdata', -36.273, 146.155, 309.3, 11.5, 77, 36, '2018-10-08 02:59:15']
# FireData Sent: ['fdata', -36.284, 146.145, 327.7, 27.6, 100, 54, '2018-10-08 02:59:15']
# FireData Sent: ['fdata', -36.282, 146.157, 344.7, 53.4, 100, 71, '2018-10-08 02:59:15']
# FireData Sent: ['fdata', -36.293, 146.148, 325.8, 25.5, 100, 52, '2018-10-08 02:59:15']
# FireData Sent: ['fdata', -36.291, 146.159, 313.2, 13.1, 56, 40, '2018-10-08 02:59:15']
# [2018-10-08 02:59:16.605900] Waiting for a connection...
# [2018-10-08 02:59:18.623702] Connection from ('127.0.0.1', 55302)
# [2018-10-08 02:59:18.623869] Connection from ('127.0.0.1', 47146)
# Climate Data Sent: ['cdata', 948700, 19, 56.3, 5.8, 8.9, ' 0.00I', '2018-10-08 02:59:18']
# FireData Sent: ['fdata', -37.635, 149.303, 320.5, 71.8, 52, 47, '2018-10-08 02:59:18']
# FireData Sent: ['fdata', -37.591, 149.33, 327.0, 54.7, 100, 53, '2018-10-08 02:59:18']
# FireData Sent: ['fdata', -37.59, 149.31, 315.5, 27.7, 51, 42, '2018-10-08 02:59:18']
# FireData Sent: ['fdata', -37.633, 149.264, 316.1, 29.5, 64, 42, '2018-10-08 02:59:18']
# FireData Sent: ['fdata', -37.585, 149.336, 327.4, 57.0, 100, 54, '2018-10-08 02:59:18']
# [2018-10-08 02:59:19.631907] Waiting for a connection...
# [2018-10-08 02:59:21.647846] Connection from ('127.0.0.1', 55306)
# [2018-10-08 02:59:21.648060] Connection from ('127.0.0.1', 47150)
# Climate Data Sent: ['cdata', 948700, 20, 57.0, 8.7, 13.0, ' 0.00I', '2018-10-08 02:59:21']
# FireData Sent: ['fdata', -37.58, 149.33100000000002, 309.0, 18.4, 69, 35, '2018-10-08 02:59:21']
# FireData Sent: ['fdata', -37.583, 149.316, 322.6, 44.6, 100, 49, '2018-10-08 02:59:21']
# FireData Sent: ['fdata', -37.38, 149.334, 304.5, 14.1, 61, 31, '2018-10-08 02:59:21']
# FireData Sent: ['fdata', -37.602, 149.295, 307.1, 24.8, 62, 33, '2018-10-08 02:59:21']
# FireData Sent: ['fdata', -37.598, 149.29, 305.4, 21.4, 64, 32, '2018-10-08 02:59:21']
# [2018-10-08 02:59:22.649781] Waiting for a connection...
# [2018-10-08 02:59:24.666343] Connection from ('127.0.0.1', 55308)
# [2018-10-08 02:59:24.666525] Connection from ('127.0.0.1', 47156)
# Climate Data Sent: ['cdata', 948700, 18, 53.3, 7.9, 14.0, ' 0.00I', '2018-10-08 02:59:24']
# FireData Sent: ['fdata', -37.596, 149.319, 312.1, 40.0, 84, 38, '2018-10-08 02:59:24']
# FireData Sent: ['fdata', -37.63, 149.232, 316.0, 49.7, 81, 42, '2018-10-08 02:59:24']
# FireData Sent: ['fdata', -37.644, 149.233, 328.7, 103.4, 100, 55, '2018-10-08 02:59:24']
# FireData Sent: ['fdata', -37.641999999999996, 149.263, 338.6, 158.5, 100, 65, '2018-10-08 02:59:24']
# FireData Sent: ['fdata', -37.634, 149.237, 344.4, 197.8, 100, 71, '2018-10-08 02:59:24']
# [2018-10-08 02:59:25.669457] Waiting for a connection...
# [2018-10-08 02:59:27.687930] Connection from ('127.0.0.1', 55312)
# [2018-10-08 02:59:27.688125] Connection from ('127.0.0.1', 47160)
# Climate Data Sent: ['cdata', 948700, 22, 56.3, 8.0, 13.0, ' 0.08G', '2018-10-08 02:59:27']
# FireData Sent: ['fdata', -37.384, 149.336, 333.0, 82.4, 84, 59, '2018-10-08 02:59:27']
# FireData Sent: ['fdata', -37.389, 149.311, 323.3, 47.2, 73, 50, '2018-10-08 02:59:27']
# FireData Sent: ['fdata', -37.605, 149.30200000000002, 356.9, 209.7, 98, 83, '2018-10-08 02:59:27']
# FireData Sent: ['fdata', -37.626999999999995, 149.261, 330.8, 64.9, 81, 57, '2018-10-08 02:59:27']
# FireData Sent: ['fdata', -37.623000000000005, 149.284, 334.3, 79.6, 84, 61, '2018-10-08 02:59:27']
# [2018-10-08 02:59:28.694247] Waiting for a connection...
# [2018-10-08 02:59:30.710796] Connection from ('127.0.0.1', 55316)
# [2018-10-08 02:59:30.710975] Connection from ('127.0.0.1', 47164)
# Climate Data Sent: ['cdata', 948700, 19, 54.1, 11.2, 18.1, ' 0.31G', '2018-10-08 02:59:30']
# FireData Sent: ['fdata', -37.6, 149.325, 359.8, 232.1, 99, 86, '2018-10-08 02:59:30']
# FireData Sent: ['fdata', -37.61, 149.279, 321.7, 35.3, 69, 48, '2018-10-08 02:59:30']
# FireData Sent: ['fdata', -37.637, 146.28799999999998, 315.5, 10.4, 60, 42, '2018-10-08 02:59:30']
# FireData Sent: ['fdata', -37.608000000000004, 149.282, 331.6, 29.7, 83, 58, '2018-10-08 02:59:30']
# FireData Sent: ['fdata', -37.62, 149.29399999999998, 336.6, 38.2, 87, 63, '2018-10-08 02:59:30']
# [2018-10-08 02:59:31.717337] Waiting for a connection...
# [2018-10-08 02:59:33.727284] Connection from ('127.0.0.1', 55320)
# [2018-10-08 02:59:33.727460] Connection from ('127.0.0.1', 47168)
# Climate Data Sent: ['cdata', 948700, 17, 50.4, 11.9, 16.9, ' 0.00G', '2018-10-08 02:59:33']
# FireData Sent: ['fdata', -37.618, 149.281, 349.6, 69.6, 95, 76, '2018-10-08 02:59:33']
# FireData Sent: ['fdata', -37.61, 149.296, 330.1, 26.4, 81, 56, '2018-10-08 02:59:33']
# FireData Sent: ['fdata', -37.603, 149.32399999999998, 324.3, 18.6, 73, 51, '2018-10-08 02:59:33']
# FireData Sent: ['fdata', -37.602, 149.311, 328.9, 26.4, 81, 55, '2018-10-08 02:59:33']
# FireData Sent: ['fdata', -37.6, 149.297, 323.9, 17.6, 69, 50, '2018-10-08 02:59:33']
# [2018-10-08 02:59:34.731144] Waiting for a connection...
# [2018-10-08 02:59:36.751782] Connection from ('127.0.0.1', 55326)
# [2018-10-08 02:59:36.751977] Connection from ('127.0.0.1', 47170)
# Climate Data Sent: ['cdata', 948700, 16, 50.8, 5.8, 12.0, ' 0.00I', '2018-10-08 02:59:36']
# FireData Sent: ['fdata', -37.382, 149.341, 314.9, 10.8, 64, 41, '2018-10-08 02:59:36']
# FireData Sent: ['fdata', -37.611, 149.27700000000002, 311.7, 16.1, 53, 38, '2018-10-08 02:59:36']
# FireData Sent: ['fdata', -37.608000000000004, 149.292, 328.7, 42.3, 100, 55, '2018-10-08 02:59:36']
# FireData Sent: ['fdata', -37.605, 149.308, 316.9, 22.7, 68, 43, '2018-10-08 02:59:36']
# FireData Sent: ['fdata', -34.282, 142.121, 327.8, 39.3, 52, 54, '2018-10-08 02:59:36']
# [2018-10-08 02:59:37.760124] Waiting for a connection...
# [2018-10-08 02:59:39.773134] Connection from ('127.0.0.1', 55328)
# [2018-10-08 02:59:39.773386] Connection from ('127.0.0.1', 47176)
# Climate Data Sent: ['cdata', 948700, 24, 55.4, 5.9, 9.9, ' 0.00I', '2018-10-08 02:59:39']
# FireData Sent: ['fdata', -37.606, 149.312, 360.7, 100.7, 100, 87, '2018-10-08 02:59:39']
# FireData Sent: ['fdata', -37.605, 149.326, 317.5, 12.0, 64, 44, '2018-10-08 02:59:39']
# FireData Sent: ['fdata', -37.61, 149.30700000000002, 353.9, 77.7, 97, 80, '2018-10-08 02:59:39']
# FireData Sent: ['fdata', -37.609, 149.32, 357.9, 89.7, 99, 84, '2018-10-08 02:59:39']
# FireData Sent: ['fdata', -37.749, 148.297, 315.5, 17.4, 50, 42, '2018-10-08 02:59:39']
# [2018-10-08 02:59:40.777508] Waiting for a connection...
# [2018-10-08 02:59:42.794489] Connection from ('127.0.0.1', 55332)
# [2018-10-08 02:59:42.794667] Connection from ('127.0.0.1', 47180)
# Climate Data Sent: ['cdata', 948700, 24, 53.4, 9.9, 15.9, ' 0.00I', '2018-10-08 02:59:42']
# FireData Sent: ['fdata', -37.946, 144.342, 333.2, 16.8, 84, 60, '2018-10-08 02:59:42']
# FireData Sent: ['fdata', -37.945, 144.35399999999998, 346.5, 40.1, 93, 73, '2018-10-08 02:59:42']
# FireData Sent: ['fdata', -38.141, 143.183, 319.5, 12.9, 68, 46, '2018-10-08 02:59:42']
# FireData Sent: ['fdata', -36.952, 144.972, 333.2, 19.9, 63, 60, '2018-10-08 02:59:42']
# FireData Sent: ['fdata', -34.965, 142.031, 328.8, 21.3, 70, 55, '2018-10-08 02:59:42']
# [2018-10-08 02:59:43.796664] Waiting for a connection...
# [2018-10-08 02:59:45.812827] Connection from ('127.0.0.1', 55336)
# [2018-10-08 02:59:45.813004] Connection from ('127.0.0.1', 47184)
# Climate Data Sent: ['cdata', 948700, 16, 46.7, 10.0, 16.9, ' 0.00I', '2018-10-08 02:59:45']
# FireData Sent: ['fdata', -37.978, 145.623, 332.4, 86.6, 84, 59, '2018-10-08 02:59:45']
# FireData Sent: ['fdata', -37.976, 145.649, 338.0, 113.1, 88, 64, '2018-10-08 02:59:45']
# FireData Sent: ['fdata', -37.758, 144.69299999999998, 332.5, 19.5, 85, 59, '2018-10-08 02:59:45']
# FireData Sent: ['fdata', -37.861999999999995, 144.175, 338.9, 34.9, 87, 65, '2018-10-08 02:59:45']
# FireData Sent: ['fdata', -38.527, 143.493, 318.7, 11.0, 64, 45, '2018-10-08 02:59:45']
# [2018-10-08 02:59:46.817635] Waiting for a connection...
# [2018-10-08 02:59:48.834139] Connection from ('127.0.0.1', 55340)
# [2018-10-08 02:59:48.835126] Connection from ('127.0.0.1', 47188)
# Climate Data Sent: ['cdata', 948700, 19, 57.2, 8.9, 15.0, ' 0.98G', '2018-10-08 02:59:48']
# FireData Sent: ['fdata', -37.332, 143.375, 319.9, 11.1, 64, 46, '2018-10-08 02:59:48']
# FireData Sent: ['fdata', -37.621, 143.447, 334.2, 104.4, 87, 61, '2018-10-08 02:59:48']
# FireData Sent: ['fdata', -37.614000000000004, 143.451, 326.8, 69.6, 81, 53, '2018-10-08 02:59:48']
# FireData Sent: ['fdata', -37.954, 143.918, 315.3, 16.5, 64, 42, '2018-10-08 02:59:48']
# FireData Sent: ['fdata', -38.167, 143.841, 312.1, 40.7, 51, 38, '2018-10-08 02:59:48']
# [2018-10-08 02:59:49.839616] Waiting for a connection...
# [2018-10-08 02:59:51.851841] Connection from ('127.0.0.1', 55346)
# [2018-10-08 02:59:51.852127] Connection from ('127.0.0.1', 47190)
# Climate Data Sent: ['cdata', 948700, 16, 50.9, 12.9, 21.0, ' 0.03G', '2018-10-08 02:59:51']
# FireData Sent: ['fdata', -38.16, 143.803, 314.2, 49.0, 62, 41, '2018-10-08 02:59:51']
# FireData Sent: ['fdata', -36.942, 143.282, 326.9, 26.7, 63, 53, '2018-10-08 02:59:51']
# FireData Sent: ['fdata', -37.864000000000004, 144.174, 314.5, 11.5, 58, 41, '2018-10-08 02:59:51']
# FireData Sent: ['fdata', -38.912, 146.27200000000002, 321.4, 42.2, 56, 48, '2018-10-08 02:59:51']
# FireData Sent: ['fdata', -36.942, 143.292, 327.5, 14.5, 67, 54, '2018-10-08 02:59:51']
# [2018-10-08 02:59:52.855115] Waiting for a connection...
# [2018-10-08 02:59:54.866504] Connection from ('127.0.0.1', 55350)
# [2018-10-08 02:59:54.866715] Connection from ('127.0.0.1', 47194)
# Climate Data Sent: ['cdata', 948700, 17, 52.5, 6.7, 12.0, ' 0.00G', '2018-10-08 02:59:54']
# FireData Sent: ['fdata', -36.94, 143.281, 342.2, 36.8, 89, 69, '2018-10-08 02:59:54']
# FireData Sent: ['fdata', -36.943000000000005, 143.286, 302.7, 18.8, 51, 29, '2018-10-08 02:59:54']
# FireData Sent: ['fdata', -36.941, 143.268, 310.5, 11.6, 80, 37, '2018-10-08 02:59:54']
# FireData Sent: ['fdata', -36.939, 143.28, 332.4, 36.7, 100, 59, '2018-10-08 02:59:54']
# FireData Sent: ['fdata', -37.863, 144.17, 333.8, 46.5, 86, 60, '2018-10-08 02:59:54']
# [2018-10-08 02:59:55.875539] Waiting for a connection...
# [2018-10-08 02:59:57.884489] Connection from ('127.0.0.1', 55354)
# [2018-10-08 02:59:57.884730] Connection from ('127.0.0.1', 47198)
# Climate Data Sent: ['cdata', 948700, 23, 59.0, 6.0, 12.0, ' 0.00I', '2018-10-08 02:59:57']
# FireData Sent: ['fdata', -36.759, 145.179, 325.9, 12.6, 68, 52, '2018-10-08 02:59:57']
# FireData Sent: ['fdata', -36.758, 145.19, 324.3, 11.0, 62, 51, '2018-10-08 02:59:57']
# FireData Sent: ['fdata', -37.213, 142.941, 324.7, 17.5, 75, 51, '2018-10-08 02:59:57']
# FireData Sent: ['fdata', -37.479, 143.358, 332.5, 30.6, 85, 59, '2018-10-08 02:59:57']
# FireData Sent: ['fdata', -37.467, 143.351, 320.2, 14.3, 72, 47, '2018-10-08 02:59:57']
# [2018-10-08 02:59:58.891801] Waiting for a connection...
# [2018-10-08 03:00:00.919356] Connection from ('127.0.0.1', 55358)
# [2018-10-08 03:00:00.919572] Connection from ('127.0.0.1', 47202)
# Climate Data Sent: ['cdata', 948700, 25, 58.3, 12.2, 22.0, ' 0.04G', '2018-10-08 03:00:00']
# FireData Sent: ['fdata', -37.477, 143.352, 366.7, 116.9, 100, 93, '2018-10-08 03:00:00']
# FireData Sent: ['fdata', -37.475, 143.365, 351.1, 68.4, 96, 77, '2018-10-08 03:00:00']
# FireData Sent: ['fdata', -37.719, 142.154, 314.4, 10.8, 63, 41, '2018-10-08 03:00:00']
# FireData Sent: ['fdata', -37.692, 143.593, 335.2, 36.4, 87, 62, '2018-10-08 03:00:00']
# FireData Sent: ['fdata', -37.69, 143.605, 353.9, 76.8, 97, 80, '2018-10-08 03:00:00']
# [2018-10-08 03:00:01.930425] Waiting for a connection...
# [2018-10-08 03:00:03.950195] Connection from ('127.0.0.1', 55360)
# [2018-10-08 03:00:03.950537] Connection from ('127.0.0.1', 47208)
# Climate Data Sent: ['cdata', 948700, 16, 48.2, 9.9, 18.1, ' 0.01G', '2018-10-08 03:00:03']
# FireData Sent: ['fdata', -36.538000000000004, 141.129, 317.0, 21.0, 60, 43, '2018-10-08 03:00:03']
# FireData Sent: ['fdata', -36.543, 141.138, 321.7, 39.4, 72, 48, '2018-10-08 03:00:03']
# FireData Sent: ['fdata', -36.341, 143.636, 332.0, 31.1, 83, 58, '2018-10-08 03:00:03']
# FireData Sent: ['fdata', -36.346, 143.631, 322.4, 14.8, 71, 49, '2018-10-08 03:00:03']
# FireData Sent: ['fdata', -37.330999999999996, 143.122, 338.8, 49.4, 90, 65, '2018-10-08 03:00:03']
# [2018-10-08 03:00:04.952893] Waiting for a connection...
# [2018-10-08 03:00:06.966249] Connection from ('127.0.0.1', 55364)
# [2018-10-08 03:00:06.966445] Connection from ('127.0.0.1', 47212)
# Climate Data Sent: ['cdata', 948700, 17, 50.8, 9.0, 15.9, ' 0.00G', '2018-10-08 03:00:06']
# FireData Sent: ['fdata', -37.329, 143.136, 335.7, 43.8, 89, 62, '2018-10-08 03:00:06']
# FireData Sent: ['fdata', -37.34, 143.123, 329.2, 97.4, 81, 56, '2018-10-08 03:00:06']
# FireData Sent: ['fdata', -36.748000000000005, 144.168, 317.2, 13.3, 62, 44, '2018-10-08 03:00:06']
# FireData Sent: ['fdata', -36.751999999999995, 144.15, 324.7, 28.8, 78, 51, '2018-10-08 03:00:06']
# FireData Sent: ['fdata', -36.759, 144.158, 333.3, 52.9, 86, 60, '2018-10-08 03:00:06']
# [2018-10-08 03:00:07.969081] Waiting for a connection...
# [2018-10-08 03:00:09.990811] Connection from ('127.0.0.1', 55368)
# [2018-10-08 03:00:09.991012] Connection from ('127.0.0.1', 47216)
# Climate Data Sent: ['cdata', 948700, 18, 53.5, 8.8, 13.0, ' 0.00I', '2018-10-08 03:00:09']
# FireData Sent: ['fdata', -36.764, 144.165, 324.1, 14.9, 78, 50, '2018-10-08 03:00:09']
# FireData Sent: ['fdata', -36.765, 144.17600000000002, 320.7, 11.4, 74, 47, '2018-10-08 03:00:09']
# FireData Sent: ['fdata', -35.325, 143.497, 309.2, 14.3, 77, 36, '2018-10-08 03:00:09']
# FireData Sent: ['fdata', -35.321, 143.502, 321.2, 27.0, 100, 48, '2018-10-08 03:00:09']
# FireData Sent: ['fdata', -35.323, 143.509, 326.7, 33.8, 100, 53, '2018-10-08 03:00:09']
# [2018-10-08 03:00:10.996358] Waiting for a connection...
# [2018-10-08 03:00:13.009703] Connection from ('127.0.0.1', 55372)
# [2018-10-08 03:00:13.010016] Connection from ('127.0.0.1', 47220)
# Climate Data Sent: ['cdata', 948700, 19, 56.1, 6.9, 12.0, ' 0.00A', '2018-10-08 03:00:13']
# FireData Sent: ['fdata', -36.156, 143.56799999999998, 315.5, 11.9, 67, 42, '2018-10-08 03:00:13']
# FireData Sent: ['fdata', -36.152, 143.578, 317.3, 13.4, 69, 44, '2018-10-08 03:00:13']
# FireData Sent: ['fdata', -37.297, 144.384, 311.7, 25.2, 72, 38, '2018-10-08 03:00:13']
# FireData Sent: ['fdata', -36.1, 143.767, 317.9, 59.9, 77, 44, '2018-10-08 03:00:13']
# FireData Sent: ['fdata', -36.098, 143.735, 333.1, 139.6, 88, 59, '2018-10-08 03:00:13']
# [2018-10-08 03:00:14.016628] Waiting for a connection...
# [2018-10-08 03:00:16.030830] Connection from ('127.0.0.1', 55376)
# [2018-10-08 03:00:16.031022] Connection from ('127.0.0.1', 47224)
# Climate Data Sent: ['cdata', 948700, 18, 57.0, 7.4, 15.0, ' 0.00I', '2018-10-08 03:00:16']
# FireData Sent: ['fdata', -36.1, 143.77200000000002, 309.1, 28.7, 65, 35, '2018-10-08 03:00:16']
# FireData Sent: ['fdata', -36.098, 143.74, 340.9, 196.8, 92, 67, '2018-10-08 03:00:16']
# FireData Sent: ['fdata', -37.586, 141.27100000000002, 319.7, 16.4, 80, 46, '2018-10-08 03:00:16']
# FireData Sent: ['fdata', -37.588, 141.259, 323.4, 20.2, 82, 50, '2018-10-08 03:00:16']
# FireData Sent: ['fdata', -37.296, 144.386, 327.9, 25.5, 65, 54, '2018-10-08 03:00:16']
# [2018-10-08 03:00:17.037074] Waiting for a connection...
# [2018-10-08 03:00:19.043995] Connection from ('127.0.0.1', 55380)
# [2018-10-08 03:00:19.044212] Connection from ('127.0.0.1', 47228)
# Climate Data Sent: ['cdata', 948700, 22, 58.0, 6.9, 12.0, ' 0.00I', '2018-10-08 03:00:19']
# FireData Sent: ['fdata', -37.287, 144.392, 323.1, 20.8, 79, 49, '2018-10-08 03:00:19']
# FireData Sent: ['fdata', -37.295, 144.377, 319.3, 16.3, 75, 46, '2018-10-08 03:00:19']
# FireData Sent: ['fdata', -35.364000000000004, 141.063, 327.5, 14.2, 72, 54, '2018-10-08 03:00:19']
# FireData Sent: ['fdata', -35.89, 145.606, 333.0, 35.9, 84, 59, '2018-10-08 03:00:19']
# FireData Sent: ['fdata', -35.889, 145.614, 329.7, 28.8, 82, 56, '2018-10-08 03:00:19']
# [2018-10-08 03:00:20.046868] Waiting for a connection...
# [2018-10-08 03:00:22.062961] Connection from ('127.0.0.1', 55384)
# [2018-10-08 03:00:22.063748] Connection from ('127.0.0.1', 47232)
# Climate Data Sent: ['cdata', 948700, 20, 55.8, 10.5, 15.9, ' 0.01G', '2018-10-08 03:00:22']
# FireData Sent: ['fdata', -35.891999999999996, 145.62, 322.8, 19.0, 71, 49, '2018-10-08 03:00:22']
# FireData Sent: ['fdata', -37.247, 141.27, 317.0, 17.1, 94, 43, '2018-10-08 03:00:22']
# FireData Sent: ['fdata', -35.937, 145.607, 324.2, 13.5, 73, 51, '2018-10-08 03:00:22']
# FireData Sent: ['fdata', -37.247, 141.278, 341.7, 88.2, 91, 68, '2018-10-08 03:00:22']
# FireData Sent: ['fdata', -37.586999999999996, 142.47899999999998, 314.5, 11.7, 58, 41, '2018-10-08 03:00:22']
# [2018-10-08 03:00:23.066234] Waiting for a connection...
# [2018-10-08 03:00:25.079587] Connection from ('127.0.0.1', 55390)
# [2018-10-08 03:00:25.079692] Connection from ('127.0.0.1', 47234)
# Climate Data Sent: ['cdata', 948700, 16, 48.4, 8.1, 15.9, ' 0.00G', '2018-10-08 03:00:25']
# FireData Sent: ['fdata', -37.805, 144.15, 329.1, 28.8, 82, 55, '2018-10-08 03:00:25']
# FireData Sent: ['fdata', -37.288000000000004, 144.39, 309.9, 22.2, 62, 36, '2018-10-08 03:00:25']
# FireData Sent: ['fdata', -37.294000000000004, 141.232, 360.5, 107.1, 100, 87, '2018-10-08 03:00:25']
# FireData Sent: ['fdata', -37.293, 141.245, 359.0, 101.7, 99, 85, '2018-10-08 03:00:25']
# FireData Sent: ['fdata', -36.851, 148.11700000000002, 319.5, 17.4, 78, 46, '2018-10-08 03:00:25']
# [2018-10-08 03:00:26.081357] Waiting for a connection...
# [2018-10-08 03:00:28.093322] Connection from ('127.0.0.1', 55392)
# [2018-10-08 03:00:28.093503] Connection from ('127.0.0.1', 47240)
# Climate Data Sent: ['cdata', 948700, 16, 48.9, 5.4, 8.9, ' 0.00I', '2018-10-08 03:00:28']
# FireData Sent: ['fdata', -37.249, 143.41299999999998, 313.7, 17.4, 72, 40, '2018-10-08 03:00:28']
# FireData Sent: ['fdata', -38.126999999999995, 143.82, 350.2, 109.2, 96, 77, '2018-10-08 03:00:28']
# FireData Sent: ['fdata', -38.116, 143.81799999999998, 317.1, 22.7, 76, 43, '2018-10-08 03:00:28']
# FireData Sent: ['fdata', -37.245, 143.42600000000002, 317.7, 20.6, 78, 44, '2018-10-08 03:00:28']
# FireData Sent: ['fdata', -37.091, 145.362, 315.1, 12.9, 72, 41, '2018-10-08 03:00:28']
# [2018-10-08 03:00:29.096954] Waiting for a connection...
